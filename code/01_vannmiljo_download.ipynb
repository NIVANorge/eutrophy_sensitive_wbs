# %%
import time

import matplotlib.pyplot as plt
import nivapy3 as nivapy
import pandas as pd

plt.style.use("ggplot")

# %% [markdown]
# # Sensitivity to eutrophication
#
# # Part 1: Data download
#
# Search Vannmiljø to identify monitoring data for the waterbodies of interest.
#
# ## 1. Waterbodies of interest

# %%
# Read WB list from MDir
xl_path = r"../data/mdir_waterbodies_list.xlsx"
wb_df = pd.read_excel(xl_path)

# Strip leading and trailing whitespace
wb_df["VannforekomstID"] = wb_df["VannforekomstID"].str.strip()

# Check unique
print("The following waterbodies are duplicated. Only the last will be kept:")
display(wb_df[wb_df.duplicated("VannforekomstID", keep=False)])
wb_df.drop_duplicates("VannforekomstID", keep="last", inplace=True)
# Out:
# The following waterbodies are duplicated. Only the last will be kept:
#     VannforekomstID   Id                               Navn.vannforekomst  \
# 141       050-106-R  NaN                                              NaN
# 142       050-105-R  NaN                                              NaN
# 153       050-105-R  R01  Bjoreio overføring fra Sysenvatnet - dam Tveito
# 154       050-106-R  R02                    Isdølo Isdalsvatnet - Bjoreio
#
#      Breddegrad  Lengdegrad  Zero  Areal (km2) Type Opphold.bunnvann  \
# 141         NaN         NaN   NaN          NaN    R              NaN
# 142         NaN         NaN   NaN          NaN    R              NaN
# 153     60.4217      7.2528   0.0       17.369    R              NaN
# 154     60.4302      7.2762   0.0        3.356    R              NaN
#
#                                              NIVA.data       oppdrag
# 141                                                NaN  Hovedoppdrag
# 142                                                NaN  Hovedoppdrag
# 153                                                NaN           NaN
# 154  Vannforekomsten oppstrøms er med i referanseel...           NaN

# %% [markdown]
# Note that many of the waterbodies are missing co-ordinate information in the file from MDir, so they cannot be plotted on the map below.

# %%
display(wb_df.head())
nivapy.spatial.quickmap(
    wb_df,
    lat_col="Breddegrad",
    lon_col="Lengdegrad",
    cluster=True,
    popup="Navn.vannforekomst",
)
# Out:
#   VannforekomstID   Id    Navn.vannforekomst  Breddegrad  Lengdegrad  Zero  \
# 0    0120000034-C  C01  Merdø - Hasseltangen     58.3998      8.7617   0.0
# 1  0121000300-1-C  C02   Grosfjorden - indre     58.3196      8.5912   0.0
# 2  0121010500-1-C  C03     Lillesandsfjorden     58.2450      8.3883   0.0
# 3  0130010301-2-C  C04    Østergapet - indre     58.1141      8.0348   0.0
# 4    0131010200-C  C05          Høllefjorden     58.0703      7.8092   0.0
#
#    Areal (km2) Type            Opphold.bunnvann NIVA.data       oppdrag
# 0        8.390    C                        Kort       NaN  Hovedoppdrag
# 1        5.574    C  Oksygenfattig (og moderat)       NaN  Hovedoppdrag
# 2        2.064    C                     Moderat        Ja  Hovedoppdrag
# 3       22.523    C                        Kort       NaN  Hovedoppdrag
# 4        1.729    C                     Moderat       NaN  Hovedoppdrag
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c47edad87aca9b264d012ea5f35753e6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c47edad87aca9b264d012ea5f35753e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c47edad87aca9b264d012ea5f35753e6 = L.map(
#                 &quot;map_c47edad87aca9b264d012ea5f35753e6&quot;,
#                 {
#                     center: [62.27429518072288, 8.534913253012048],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_797b80521e759bc10a46d57a1de36111 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_797b80521e759bc10a46d57a1de36111.addTo(map_c47edad87aca9b264d012ea5f35753e6);
#
#
#             var feature_group_d10c50ec2cc7fba0653c99cad6b773ee = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_cluster_b6f7d4fe417b8435fa41b27df81b6881 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_5c941452fba2c4e23b869abb44480343 = L.marker(
#                 [58.3998, 8.7617],
#                 {}
#             ).addTo(marker_cluster_b6f7d4fe417b8435fa41b27df81b6881);
#
#
#         var popup_f673927b79ef02c1cb26d88c4c28687b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8425c7cacb300c6427380f87a2c88fb6 = $(`&lt;div id=&quot;html_8425c7cacb300c6427380f87a2c88fb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Merdø - Hasseltangen&lt;/div&gt;`)[0];
#                 popup_f673927b79ef02c1cb26d88c4c28687b.setContent(html_8425c7cacb300c6427380f87a2c88fb6);
#
#
#
#         marker_5c941452fba2c4e23b869abb44480343.bindPopup(popup_f673927b79ef02c1cb26d88c4c28687b)
#         ;
#
#
#
#
#             var marker_02d0b401567aba362c025b7b78b52a71 = L.marker(
#                 [58.3196, 8.5912],
#                 {}
#             ).addTo(marker_cluster_b6f7d4fe417b8435fa41b27df81b6881);
#
#
#         var popup_678ce3b14f737432d77dfc807c0541c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c170ef89715e71b8c81dfb343f9c7417 = $(`&lt;div id=&quot;html_c170ef89715e71b8c81dfb343f9c7417&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Grosfjorden - indre&lt;/div&gt;`)[0];
#                 popup_678ce3b14f737432d77dfc807c0541c0.setContent(html_c170ef89715e71b8c81dfb343f9c7417);
#
#
#
#         marker_02d0b401567aba362c025b7b78b52a71.bindPopup(popup_678ce3b14f737432d77dfc807c0541c0)
#         ;
#
#
#
#
#             var marker_830ab070a1f1963121153870dbdbb378 = L.marker(
#                 [58.245, 8.3883],
#                 {}
#             ).addTo(marker_cluster_b6f7d4fe417b8435fa41b27df81b6881);
#
#
#         var popup_2de590cff095edbcc3440c2b42036a65 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_45bb909dafe2258cc8d994c039badb14 = $(`&lt;div id=&quot;html_45bb909dafe2258cc8d994c039badb14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lillesandsfjorden&lt;/div&gt;`)[0];
#                 popup_2de590cff095edbcc3440c2b42036a65.setContent(html_45bb909dafe2258cc8d994c039badb14);
#
#
#
#         marker_830ab070a1f1963121153870dbdbb378.bindPopup(popup_2de590cff095edbcc3440c2b42036a65)
#         ;
#
#
#
#
#             var marker_5a1d0f9a7e0fa3e1f71c5c3f2117309c = L.marker(
#                 [58.1141, 8.0348],
#                 {}
#             ).addTo(marker_cluster_b6f7d4fe417b8435fa41b27df81b6881);
#
#
#         var popup_3a191e3a186eabc8662f67d56153cd5f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ec28ae13a5551d2849450af784a411f2 = $(`&lt;div id=&quot;html_ec28ae13a5551d2849450af784a411f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Østergapet - indre&lt;/div&gt;`)[0];
#                 popup_3a191e3a186eabc8662f67d56153cd5f.setContent(html_ec28ae13a5551d2849450af784a411f2);
#
#
#
#         marker_5a1d0f9a7e0fa3e1f71c5c3f2117309c.bindPopup(popup_3a191e3a186eabc8662f67d56153cd5f)
#         ;
#
#
#
#
#             var marker_76caac0ec49c6ed3d20511d190ea0b1c = L.marker(
#                 [58.0703, 7.8092],
#                 {}
#             ).addTo(marker_cluster_b6f7d4fe417b8435fa41b27df81b6881);

# %% [markdown]
# ## 2. User options

# %%
# Define parameters and time period of interest
pars = [
    "ANDEKNPR",
    "ANDEKNSK",
    "ANDEKNSK_PKT",
    "ANEQR_E",
    "ANNEQR_E",
    "ANNVGR",
    "ANNVGRTO",
    "ANTIZM",
    "ASPT",
    "BENEQR_E",
    "BENEQR_G",
    "CYANOM",
    "FIEINDW3",
    "HBDEKNPS",
    "HBI2",
    "KLFA",
    "LBNEQR_E",
    "LBNEQR_G",
    "MAEQR_E",
    "MAH",
    "MANEQR_E",
    "MBDEKNPS",
    "MBDEKNSK",
    "MBDEKNSK_PKT",
    "MBNEQR_G",
    "MBNEQR_MID",
    "MFNEQR_E",
    "MHDEKNPS",
    "MHH",
    "MSMDI1",
    "MSMDI2",
    "MSMDI3",
    "N-NH3",
    "N-NH4",
    "N-NO2",
    "N-NO3",
    "N-SNOX",
    "N-TOT",
    "NQI1",
    "NQI1_MID",
    "O2",
    "P-ORTO",
    "P-PART",
    "P-PO4",
    "P-TOT",
    "PIT",
    "PON",
    "POP",
    "PPBIOMTOVO",
    "PPNEQR_E",
    "PPTI",
    "RSL4",
    "RSL5",
    "RSLA1",
    "RSLA2",
    "RSLA3",
    "SI-SIO2",
    "SIO2",
    "STS",
    "TIANTL",
    "TOC",
    "TON",
    "TSM",
]
st_yr, end_yr = 1960, 2024
res_xlsx = r"../data/vannmiljo_export_for_waterbodies.xlsx"

# %%
# # Query API
# wb_list = wb_df['VannforekomstID'].dropna().tolist()
# filter_dict = {
#     "WaterBodyIDFilter": wb_list,
#     "FromDateSamplingTime": f"{st_yr}-01-01",
#     "ToDateSamplingTime": f"{end_yr}-12-31",
#     # "ParameterIDFilter": pars,
#     "FromRegDate": "1900-01-01",
# }
# df = nivapy.da.post_data_to_vannmiljo("GetRegistrations", data=filter_dict)
# df.rename(columns={'CoordX':'UTM33East', 'CoordY':'UTM33North'}, inplace=True)
# df.to_excel(res_xl_path)

# %%
def query_api_with_retries(data, retries=3, delay=5):
    for attempt in range(retries):
        try:
            df = nivapy.da.post_data_to_vannmiljo("GetRegistrations", data=data)
            return df
        except KeyError as e:
            # print(f"  Attempt {attempt + 1} failed: {e}")
            if attempt < retries - 1:
                time.sleep(delay)
            else:
                print("  All retry attempts failed.")
                return pd.DataFrame()

# %%
# %%time
# Query API
wb_list = wb_df["VannforekomstID"].dropna().tolist()
df_list = []
for wb_id in wb_list:
    print("Processing:", wb_id)
    filter_dict = {
        "WaterBodyIDFilter": [wb_id],
        "FromDateSamplingTime": f"{st_yr}-01-01",
        "ToDateSamplingTime": f"{end_yr}-12-31",
        "ParameterIDFilter": pars,
        "FromRegDate": "1900-01-01",
    }
    df = query_api_with_retries(data=filter_dict, retries=3, delay=5)
    if len(df) > 0:
        df_list.append(df)
    else:
        print("  No data available.")
df = pd.concat(df_list, axis="rows")

# Tidy
df["SamplingTime"] = pd.to_datetime(df["SamplingTime"])
df.rename(columns={"CoordX": "UTM33East", "CoordY": "UTM33North"}, inplace=True)
drop_cols = [
    "WaterRegistrationID",
    "WaterLocationID",
    "Name_Alternative",
    "SourceID",
    "ListName",
    "UnitID",
    "SampleID",
    "Username",
    "RegDate",
    "LastEditDate",
    "Archive",
    "FeatureType",
    "WaterCategory",
]
df.drop(columns=drop_cols, inplace=True)

# Save
df.to_excel(res_xlsx, index=False)
# Out:
# Processing: 0120000034-C
# Processing: 0121000300-1-C
# Processing: 0121010500-1-C
# Processing: 0130010301-2-C
# Processing: 0131010200-C
# Processing: 0132010100-C
# Processing: 0201000030-2-C
# Processing: 0201010300-C
# Processing: 0240010201-C
# Processing: 0241000030-C
# Processing: 0242000030-C
# Processing: 0242000032-C
# Processing: 0242010101-3-C
# Processing: 0242011101-C
# Processing: 0242040102-C
# Processing: 0242050100-2-C
# Processing: 0260010501-6-C
# Processing: 0260020801-C
# Processing: 0260020802-C
# Processing: 0260020900-C
# Processing: 0260021000-C
# Processing: 0260040101-C
# Processing: 0260040800-C
# Processing: 0260050500-C
# Processing: 0261010500-2-C
# Processing: 0261010600-C
# Processing: 0261010702-3-C
# Processing: 0261010800-2-C
# Processing: 0261010800-4-C
# Processing: 0261010800-9-C
# Processing: 0261020100-2-C
# Processing: 0261030201-2-C
# Processing: 0261030202-C
# Processing: 0261030300-2-C
# Processing: 0281010201-3-C
#   No data available.
# Processing: 0281010700-C
# Processing: 0281010900-2-C
# Processing: 0281011000-C
# Processing: 0281011100-2-C
# Processing: 0301020300-1-C
# Processing: 0301021201-C
# Processing: 0301021203-1-C
# Processing: 0301021203-2-C
# Processing: 0301021300-3-C
# Processing: 0301021300-4-C
# Processing: 0301021400-C
# Processing: 0301021500-C
# Processing: 0301021800-2-C
# Processing: 0301021900-C
# Processing: 0301022000-1-C
# Processing: 0302012203-C
# Processing: 0303000030-C
# Processing: 0303011202-2-C
# Processing: 0303011202-6-C
# Processing: 0320040700-2-C
# Processing: 0320040900-10-C
# Processing: 0320040900-3-C
# Processing: 0320041000-10-C
# Processing: 0320041200-10-C
# Processing: 0320041500-3-C
# Processing: 0341010200-C
# Processing: 0361040101-C
# Processing: 0361040700-3-C
# Processing: 0361040800-C
# Processing: 0362011000-2-C
# Processing: 0363011100-2-C
# Processing: 0363011200-3-C
# Processing: 0363020900-C
# Processing: 0364030100-2-C
# Processing: 0365010601-7-C
# Processing: 0401020100-1-C
# Processing: 0401020100-3-C
#   No data available.
# Processing: 0401020400-3-C
# Processing: 0401020500-2-C
# Processing: 0402020900-11-C
# Processing: 0402021000-2-C
# Processing: 0420020100-10-C
# Processing: 0240010202-C
# Processing: 0242010702-1-C
# Processing: 0242040101-1-C
# Processing: 0242040103-C
# Processing: 0242040802-5-C
# Processing: 0242040902-C
# Processing: 0261010200-6-C
# Processing: 0261010401-C
# Processing: 0280021301-C
# Processing: 0282012100-3-C
# Processing: 0301010700-6-C
# Processing: 0301011000-2-C
# Processing: 0301011204-C
# Processing: 0301011300-C
# Processing: 0301021002-2-C
# Processing: 0341010301-2-C
# Processing: 0361040400-C
#   No data available.
# Processing: 0365010601-2-C
#   No data available.
# Processing: 0365010602-1-C
#   No data available.
# Processing: 0420030300-4-C
# Processing: 0420030600-5-C
# Processing: 0130010302-2-C
# Processing: 0130010302-3-C
# Processing: 0201020500-1-C
# Processing: 0241000031-1-C
# Processing: 0242010101-2-C
# Processing: 0242010401-2-C
# Processing: 0242030200-C
# Processing: 0242041000-C
#   No data available.
# Processing: 0260010300-C
# Processing: 0260020300-C
# Processing: 0260050100-C
# Processing: 0261030201-1-C
# Processing: 0281010900-1-C
# Processing: 0282010400-C
# Processing: 0301020703-C
# Processing: 0301021002-1-C
# Processing: 0301021300-1-C
# Processing: 0302011300-3-C
# Processing: 0302012400-2-C
# Processing: 0303010901-C
# Processing: 0303020500-2-C
# Processing: 0320040300-C
# Processing: 0320040400-3-C
# Processing: 0320040500-16-C
# Processing: 0320040500-3-C
# Processing: 0321010300-2-C
# Processing: 0321040300-2-C
# Processing: 0341010301-1-C
# Processing: 0364000030-3-C
#   No data available.
# Processing: 0364040300-5-C
#   No data available.
# Processing: 0401020500-1-C
# Processing: 0401030300-2-C
# Processing: 0403040104-1-C
# Processing: 0403040300-C
# Processing: 0403040401-1-C
# Processing: 0403040401-2-C
# Processing: 0424030500-5-C
# Processing: 0424030601-C
# Processing: 026-1409-L
# Processing: 062-2085-L
# Processing: 062-2091-L
# Processing: 036-1865-L
# Processing: 062-2084-L
# Processing: 156-480-R
#   No data available.
# Processing: 002-693-R
# Processing: 103-93-R
# Processing: 103-97-R
# Processing: 196-250-R
# Processing: 196-274-R
# Processing: 196-275-R
# Processing: 196-414-R
# Processing: 196-49-R
#   No data available.
# Processing: 234-982-R
# Processing: 050-105-R
# Processing: 050-106-R
# <timed exec>:18: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
# CPU times: user 6min 35s, sys: 24 s, total: 6min 59s
# Wall time: 39min 22s

# %%
# Print summary
data_wbs = df["WaterBodyID"].unique().tolist()
no_data_wbs = list(set(wb_list) - set(data_wbs))
site_ids = df["WaterLocationCode"].unique().tolist()
par_ids = df["ParameterID"].unique().astype(str).tolist()
print(f"{len(data_wbs)} out of {len(wb_list)} waterbodies have at least some data.")
print(
    f"\nThe following {len(no_data_wbs)} out of {len(wb_list)} waterbodies have no data:"
)
print(no_data_wbs)
print(f"\nData are available from {len(site_ids)} monitoring stations.")
print(f"\nThe following {len(par_ids)} parameters have been measured:")
print(sorted(par_ids))
# Out:
# 143 out of 153 waterbodies have at least some data.
#
# The following 10 out of 153 waterbodies have no data:
# ['0364000030-3-C', '0281010201-3-C', '0365010602-1-C', '156-480-R', '0365010601-2-C', '0401020100-3-C', '0242041000-C', '0361040400-C', '196-49-R', '0364040300-5-C']
#
# Data are available from 3282 monitoring stations.
#
# The following 53 parameters have been measured:
# ['ANDEKNSK', 'ANDEKNSK_PKT', 'ANEQR_E', 'ANNVGR', 'ANNVGRTO', 'ANTIZM', 'ASPT', 'BENEQR_E', 'BENEQR_G', 'CYANOM', 'HBDEKNPS', 'KLFA', 'LBNEQR_E', 'LBNEQR_G', 'MAH', 'MANEQR_E', 'MBDEKNSK', 'MBDEKNSK_PKT', 'MBNEQR_G', 'MBNEQR_MID', 'MFNEQR_E', 'MHH', 'MSMDI2', 'MSMDI3', 'N-NH3', 'N-NH4', 'N-NO2', 'N-NO3', 'N-SNOX', 'N-TOT', 'NQI1', 'NQI1_MID', 'O2', 'P-ORTO', 'P-PART', 'P-PO4', 'P-TOT', 'PIT', 'PON', 'POP', 'PPBIOMTOVO', 'PPNEQR_E', 'PPTI', 'RSL4', 'RSLA1', 'RSLA2', 'RSLA3', 'SI-SIO2', 'SIO2', 'STS', 'TIANTL', 'TOC', 'TSM']

# %%
# Plot stations
stn_df = df[["WaterLocationCode", "UTM33East", "UTM33North"]].drop_duplicates()
stn_df["utm_zone"] = 33
stn_df = nivapy.spatial.utm_to_wgs84_dd(
    stn_df, zone="utm_zone", east="UTM33East", north="UTM33North"
)
nivapy.spatial.quickmap(
    stn_df,
    lat_col="lat",
    lon_col="lon",
    cluster=True,
    popup="WaterLocationCode",
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_68c76d4aba93390a57dfe29d38cf2858 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_68c76d4aba93390a57dfe29d38cf2858&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_68c76d4aba93390a57dfe29d38cf2858 = L.map(
#                 &quot;map_68c76d4aba93390a57dfe29d38cf2858&quot;,
#                 {
#                     center: [62.28920167391705, 8.669319819246988],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_84be3079b477914e5fbf7a24562e4023 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_84be3079b477914e5fbf7a24562e4023.addTo(map_68c76d4aba93390a57dfe29d38cf2858);
#
#
#             var feature_group_53f67df69f1efca7acd5ea51cd8a0069 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_cluster_55700239f9bcb1a80e56368629909573 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_abdcdd7a7d4116a0cdefae6e01feb666 = L.marker(
#                 [58.40900000047797, 8.76183000107554],
#                 {}
#             ).addTo(marker_cluster_55700239f9bcb1a80e56368629909573);
#
#
#         var popup_f68d7e147c7084d3ea5d591423dca093 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_215a6d834843fc85786893403559e384 = $(`&lt;div id=&quot;html_215a6d834843fc85786893403559e384&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;01.20-81799&lt;/div&gt;`)[0];
#                 popup_f68d7e147c7084d3ea5d591423dca093.setContent(html_215a6d834843fc85786893403559e384);
#
#
#
#         marker_abdcdd7a7d4116a0cdefae6e01feb666.bindPopup(popup_f68d7e147c7084d3ea5d591423dca093)
#         ;
#
#
#
#
#             var marker_17f7948ef2369a32bb16e497be1cfbfd = L.marker(
#                 [58.39550000035632, 8.762666667279092],
#                 {}
#             ).addTo(marker_cluster_55700239f9bcb1a80e56368629909573);
#
#
#         var popup_b8218cb8b2d33ff5f5c2a0e087544bff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ecc59aa728b1f41dfc67185dccf619e5 = $(`&lt;div id=&quot;html_ecc59aa728b1f41dfc67185dccf619e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;01.20-64373&lt;/div&gt;`)[0];
#                 popup_b8218cb8b2d33ff5f5c2a0e087544bff.setContent(html_ecc59aa728b1f41dfc67185dccf619e5);
#
#
#
#         marker_17f7948ef2369a32bb16e497be1cfbfd.bindPopup(popup_b8218cb8b2d33ff5f5c2a0e087544bff)
#         ;
#
#
#
#
#             var marker_87470cf8096c787f1b5358e3f98c2c49 = L.marker(
#                 [58.41015461651932, 8.762115529217326],
#                 {}
#             ).addTo(marker_cluster_55700239f9bcb1a80e56368629909573);
#
#
#         var popup_0b28e1d037465135002f09831897727a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6f9db1fe962d72969ea5832fc65d56b7 = $(`&lt;div id=&quot;html_6f9db1fe962d72969ea5832fc65d56b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;01.20-32188&lt;/div&gt;`)[0];
#                 popup_0b28e1d037465135002f09831897727a.setContent(html_6f9db1fe962d72969ea5832fc65d56b7);
#
#
#
#         marker_87470cf8096c787f1b5358e3f98c2c49.bindPopup(popup_0b28e1d037465135002f09831897727a)
#         ;
#
#
#
#
#             var marker_f8dfe544cac6832a786eebc7cf5e5b3b = L.marker(
#                 [58.396169999604886, 8.763000000654333],
#                 {}
#             ).addTo(marker_cluster_55700239f9bcb1a80e56368629909573);
#
#
#         var popup_bc94c7e3e91a62229b983de184c6976c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_be115c9072f24ae81f3073719e875cda = $(`&lt;div id=&quot;html_be115c9072f24ae81f3073719e875cda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;01.20-81800&lt;/div&gt;`)[0];
#                 popup_bc94c7e3e91a62229b983de184c6976c.setContent(html_be115c9072f24ae81f3073719e875cda);
#
#
#
#         marker_f8dfe544cac6832a786eebc7cf5e5b3b.bindPopup(popup_bc94c7e3e91a62229b983de184c6976c)
#         ;
#
#
#
#
#             var marker_35b456ac04c48ac87021e78e3c56f191 = L.marker(
#                 [58.41215000013722, 8.76432999989221],
#                 {}
