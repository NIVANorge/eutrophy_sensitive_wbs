# %%
import time
import warnings

import altair as alt
import folium
import nivapy3 as nivapy
import pandas as pd
from altair import Chart
from folium import IFrame
from folium.plugins import MarkerCluster
from IPython.display import display

warnings.simplefilter(action="ignore", category=FutureWarning)

# %% [markdown]
# # Get $O_2$ data from Vannmiljø
#
# Download all O2 data for Oslofjorden from Vannmiljø. See e-mails from Anette and Elianne on 31.03.2025.

# %%
# Vassdragsområder list. 001 to 017 for the whole Oslofjord, as defined by MDir
vassoms = [f"{id:03d}" for id in range(1, 18)]

# Parameters of interest
pars = ["O2"]

# %%
def query_api_with_retries(data, retries=3, delay=5):
    for attempt in range(retries):
        try:
            df = nivapy.da.post_data_to_vannmiljo("GetRegistrations", data=data)
            return df
        except KeyError as e:
            # print(f"  Attempt {attempt + 1} failed: {e}")
            if attempt < retries - 1:
                time.sleep(delay)
            else:
                print("  All retry attempts failed.")
                return pd.DataFrame()

# %%
# Get all stations around Oslofjord
data = {"VassdragsomradeIDFilter": vassoms}
stn_df = nivapy.da.post_data_to_vannmiljo("GetWaterLocations", data=data)

# %%
# %%time
# Query API
df_list = []
for vassom in vassoms:
    print("Processing:", vassom)
    filter_dict = {
        "VassdragsomradeIDFilter": [vassom],
        "FromDateSamplingTime": f"1900-01-01",
        "ToDateSamplingTime": f"2025-12-31",
        "ParameterIDFilter": pars,
        "FromRegDate": "1900-01-01",
    }
    df = query_api_with_retries(data=filter_dict, retries=3, delay=5)
    if len(df) > 0:
        df_list.append(df)
    else:
        print("  No data available.")
df = pd.concat(df_list, axis="rows")

# Tidy
df["SamplingTime"] = pd.to_datetime(df["SamplingTime"])

# Save
res_xlsx = r"../data/o2_data/o2_data_vassoms_001-017.xlsx"
df.to_excel(res_xlsx, index=False)
# Out:
# Processing: 001
# Processing: 002
# Processing: 003
# Processing: 004
# Processing: 005
# Processing: 006
# Processing: 007
# Processing: 008
# Processing: 009
# Processing: 010
# Processing: 011
# Processing: 012
# Processing: 013
# Processing: 014
# Processing: 015
# Processing: 016
# Processing: 017
# CPU times: user 4min 21s, sys: 6.45 s, total: 4min 27s
# Wall time: 5min 37s

# %%
# Filter stations to just those with O2 data
o2_stn_list = df["WaterLocationCode"].unique().tolist()
stn_df = stn_df.query("WaterLocationCode in @o2_stn_list")
stn_xlsx = r"../data/o2_data/o2_stns_vassoms_001-017.xlsx"
stn_df.to_excel(stn_xlsx, index=False)

# %%
avg_df = (
    df[["WaterLocationCode", "SamplingTime", "Unit", "RegValue"]]
    .groupby(["WaterLocationCode", "SamplingTime", "Unit"])
    .mean()
    .reset_index()
)
avg_stn_df = stn_df[["WaterLocationCode", "CoordY_dg", "CoordX_dg"]].copy()

# %%
def create_chart(data):
    unit = data["Unit"].iloc[0]
    line = (
        alt.Chart(data)
        .mark_line()
        .encode(
            x="SamplingTime:T",
            y=alt.Y("RegValue:Q", title=f"O2 ({unit})"),
            tooltip=["SamplingTime:T", "RegValue:Q"],
        )
    )
    points = line.mark_circle()
    chart = line + points
    chart = chart.properties(width=300, height=200)
    return chart

# %%
# Map
m = folium.Map(
    location=[avg_stn_df["CoordY_dg"].mean(), avg_stn_df["CoordX_dg"].mean()],
    zoom_start=6,
)
marker_cluster = MarkerCluster().add_to(m)

# Add markers
for idx, row in avg_stn_df.iterrows():
    location_code = row["WaterLocationCode"]
    lat = row["CoordY_dg"]
    lon = row["CoordX_dg"]

    # Create chart
    location_data = avg_df[avg_df["WaterLocationCode"] == location_code]
    chart = create_chart(location_data)

    # Convert to HTML
    html = chart.to_html()
    iframe = IFrame(html, width=400, height=300)
    popup = folium.Popup(iframe, max_width=400)

    # Add to marker cluster
    folium.Marker(location=[lat, lon], popup=popup).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2545f305bd1e04dbdf9348d87c204c0e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2545f305bd1e04dbdf9348d87c204c0e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2545f305bd1e04dbdf9348d87c204c0e = L.map(
#                 &quot;map_2545f305bd1e04dbdf9348d87c204c0e&quot;,
#                 {
#                     center: [59.637092904271405, 10.346121071074046],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e7dfabbd1b2212ef51f87d9ec4335eec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e7dfabbd1b2212ef51f87d9ec4335eec.addTo(map_2545f305bd1e04dbdf9348d87c204c0e);
#
#
#             var marker_cluster_5c3c87d333d0ffa1db12f0cc5281da22 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_3cd51ccc4561775b1623374b53e45917 = L.marker(
#                 [60.38410332308515, 10.554609454186522],
#                 {}
#             ).addTo(marker_cluster_5c3c87d333d0ffa1db12f0cc5281da22);
#
#
#         var popup_3c3101631279a83585a7b093d2be2e91 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var i_frame_2619b41a04ddb577e16578dc1cefa279 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;400&quot; style=&quot;border:none !important;&quot; height=&quot;300&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_3c3101631279a83585a7b093d2be2e91.setContent(i_frame_2619b41a04ddb577e16578dc1cefa279);
#
#
#
#         marker_3cd51ccc4561775b1623374b53e45917.bindPopup(popup_3c3101631279a83585a7b093d2be2e91)
#         ;
#
#
#
#
#             var marker_0a08c9dd9f838c16793c9c790a119de6 = L.marker(
#                 [60.08137257224981, 10.313845571610706],
#                 {}
#             ).addTo(marker_cluster_5c3c87d333d0ffa1db12f0cc5281da22);
#
#
#         var popup_2ec46988af762f8ebb4bd736141b4a2e = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var i_frame_16ca9c5864b3fa2f2def6eb6eda853fc = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;400&quot; style=&quot;border:none !important;&quot; height=&quot;300&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_2ec46988af762f8ebb4bd736141b4a2e.setContent(i_frame_16ca9c5864b3fa2f2def6eb6eda853fc);
#
#
#
#         marker_0a08c9dd9f838c16793c9c790a119de6.bindPopup(popup_2ec46988af762f8ebb4bd736141b4a2e)
#         ;
#
#
#
#
#             var marker_c408890b0960f6ee457ce73eac8d5834 = L.marker(
#                 [59.10318696723219, 11.294270809332373],
#                 {}
#             ).addTo(marker_cluster_5c3c87d333d0ffa1db12f0cc5281da22);
#
#
#         var popup_c44b86f50a2610aefd76c1cf4556d5ad = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var i_frame_aa757c4b9cb24cb3c1e62c5274670487 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;400&quot; style=&quot;border:none !important;&quot; height=&quot;300&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_c44b86f50a2610aefd76c1cf4556d5ad.setContent(i_frame_aa757c4b9cb24cb3c1e62c5274670487);
#
#
#
#         marker_c408890b0960f6ee457ce73eac8d5834.bindPopup(popup_c44b86f50a2610aefd76c1cf4556d5ad)
#         ;
#
#
#
#
#             var marker_04dba9d71ee78c62e9b77958c0c7a34b = L.marker(
#                 [59.08995099727137, 11.380677987885763],
#                 {}
#             ).addTo(marker_cluster_5c3c87d333d0ffa1db12f0cc5281da22);
#
#
#         var popup_0ab98611839f1b10e7dd275192e628c3 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var i_frame_72bfd326fc90c5942e4ff8b1a0fe250b = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;400&quot; style=&quot;border:none !important;&quot; height=&quot;300&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_0ab98611839f1b10e7dd275192e628c3.setContent(i_frame_72bfd326fc90c5942e4ff8b1a0fe250b);
#
#
#
#         marker_04dba9d71ee78c62e9b77958c0c7a34b.bindPopup(popup_0ab98611839f1b10e7dd275192e628c3)
#         ;
#
#
#
#
#             var marker_9dfe21299f38024a00e5721ac9c93f9a = L.marker(
#                 [59.0644740601838, 11.398103650782582],
#                 {}
#             ).add
